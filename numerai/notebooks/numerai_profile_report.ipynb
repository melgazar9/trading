# %% [markdown]
# ### Imports

# %%
# General Python
import os
import sys

### API
import numerapi

### Data Manipulation
import pandas as pd
import numpy as np

### EDA
from pandas_profiling import ProfileReport

### ML
from sklearn.ensemble import *
from xgboost import XGBRegressor, XGBRFRegressor

# %%
os.chdir('../..')

# %%
os.environ['NUMEXPR_MAX_THREADS'] = '32'
os.environ['NUMEXPR_NUM_THREADS'] = '16'

# %% [markdown]
# ### Global Variables

# %%
import configparser
config = configparser.ConfigParser()
config.read('numerai/numerai_keys.ini')
# Out:
# ['numerai/numerai_keys.ini']

# %%
DOWNLOAD_DATA = False
DF_TRAIN_PATH = 'C:/Users/Matt/trading/numerai/numerai_dataset_255/numerai_training_data.csv'
napi = numerapi.NumerAPI(config['KEYS']['NUMERAI_PUBLIC_KEY'], config['KEYS']['NUMERAI_SECRET_KEY'])

# download data
if DOWNLOAD_DATA:
    napi.download_current_dataset(unzip=True)

# %%
df_train = pd.read_csv(DF_TRAIN_PATH)

# %%
df_train.head()
# Out:
#                  id   era data_type  feature_intelligence1  \
# 0  n000315175b67977  era1     train                   0.00
# 1  n0014af834a96cdd  era1     train                   0.00
# 2  n001c93979ac41d4  era1     train                   0.25
# 3  n0034e4143f22a13  era1     train                   1.00
# 4  n00679d1a636062f  era1     train                   0.25
#
#    feature_intelligence2  feature_intelligence3  feature_intelligence4  \
# 0                   0.50                   0.25                   0.00
# 1                   0.00                   0.00                   0.25
# 2                   0.50                   0.25                   0.25
# 3                   0.00                   0.00                   0.50
# 4                   0.25                   0.25                   0.25
#
#    feature_intelligence5  feature_intelligence6  feature_intelligence7  ...  \
# 0                    0.5                   0.25                   0.25  ...
# ...

# %%
report = ProfileReport(df_train, minimal = True)

# %%
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-03-18 04:08:26.921675&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
